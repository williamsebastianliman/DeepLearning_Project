# %% [markdown]
# # QuickDraw Sketch Classifier Training
#
# ## Imports and Configuration

# %%
import os
import time
import random
import shutil
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from datetime import datetime

DATA_DIR = "quickdraw_images_dedup"
TMP_DATA_DIR = "quickdraw_images_100per"
IMG_SIZE = (128, 128)
BATCH_SIZE = 128  
EPOCHS = 30
SEED = 42
OUTPUT_MODEL = "quickdraw_scratch_final.keras"
BEST_CHECKPOINT = "best_scratch_ckpt.keras"

MIXUP_ALPHA = 0.0 
LABEL_SMOOTHING = 0.05  
L2_WEIGHT = 1e-4
DROPOUT = 0.3

WARMUP_EPOCHS = 2
BASE_LR = 1e-4  
MIN_LR = 1e-7

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print(f"[INFO] TensorFlow version: {tf.__version__}")
print(f"[INFO] GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")
# Out:
# [INFO] TensorFlow version: 2.10.0
# [INFO] GPU available: True

# %% [markdown]
# ## Dataset Preparation

# %%
if not os.path.isdir(DATA_DIR):
    raise FileNotFoundError(f"Data directory '{DATA_DIR}' not found")

label_dirs = sorted([d for d in os.listdir(DATA_DIR) 
                     if os.path.isdir(os.path.join(DATA_DIR, d))])
if not label_dirs:
    raise RuntimeError(f"No label subdirectories found in '{DATA_DIR}'")

def count_images(root):
    counts = {}
    total = 0
    for class_name in sorted(os.listdir(root)):
        class_path = os.path.join(root, class_name)
        if not os.path.isdir(class_path):
            continue
        n_images = sum(1 for f in os.listdir(class_path) 
                      if f.lower().endswith(('.png', '.jpg', '.jpeg')))
        counts[class_name] = n_images
        total += n_images
    return counts, total

if os.path.exists(TMP_DATA_DIR):
    try:
        shutil.rmtree(TMP_DATA_DIR)
    except Exception:
        pass
os.makedirs(TMP_DATA_DIR, exist_ok=True)

MAX_PER_CLASS = 1500

for class_name in label_dirs:
    src_dir = os.path.join(DATA_DIR, class_name)
    dst_dir = os.path.join(TMP_DATA_DIR, class_name)
    os.makedirs(dst_dir, exist_ok=True)
    imgs = [f for f in os.listdir(src_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    imgs = sorted(imgs)
    if len(imgs) == 0:
        continue
    if len(imgs) <= MAX_PER_CLASS:
        chosen = imgs
    else:
        random.seed(SEED)
        chosen = imgs.copy()
        random.shuffle(chosen)
        chosen = chosen[:MAX_PER_CLASS]
    for fname in chosen:
        src = os.path.join(src_dir, fname)
        dst = os.path.join(dst_dir, fname)
        if os.path.exists(dst):
            continue
        try:
            os.symlink(os.path.abspath(src), os.path.abspath(dst))
        except Exception:
            try:
                shutil.copy2(src, dst)
            except Exception:
                pass

class_counts, total_images = count_images(TMP_DATA_DIR)
print(f"[INFO] Using temporary dataset '{TMP_DATA_DIR}' with {len(class_counts)} classes, {total_images:,} total images")
# Out:
# [INFO] Using temporary dataset 'quickdraw_images_100per' with 26 classes, 39,000 total images

# %% [markdown]
# ## Data Loading (80:10:10 Split)

# %%
print("[INFO] Loading datasets...")

raw_train = keras.utils.image_dataset_from_directory(
    TMP_DATA_DIR,
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.2,
    subset='training',
    seed=SEED,
    shuffle=True
)

raw_val_test = keras.utils.image_dataset_from_directory(
    TMP_DATA_DIR,
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.2,
    subset='validation',
    seed=SEED,
    shuffle=False
)

class_names = raw_train.class_names
NUM_CLASSES = len(class_names)
print(f"[INFO] Classes: {NUM_CLASSES}")

AUTOTUNE = tf.data.AUTOTUNE
train_steps = int(tf.data.experimental.cardinality(raw_train).numpy())
val_test_steps = int(tf.data.experimental.cardinality(raw_val_test).numpy())

val_steps = val_test_steps // 2
test_steps = val_test_steps - val_steps

raw_val = raw_val_test.take(val_steps)
raw_test = raw_val_test.skip(val_steps)

print(f"[INFO] Train steps: {train_steps}, Val steps: {val_steps}, Test steps: {test_steps}")
# Out:
# [INFO] Loading datasets...
# Found 39000 files belonging to 26 classes.
# Using 31200 files for training.
# Found 39000 files belonging to 26 classes.
# Using 7800 files for validation.
# [INFO] Classes: 26
# [INFO] Train steps: 244, Val steps: 30, Test steps: 31

# %% [markdown]
# ## Data Preprocessing and Augmentation

# %%
def augment_batch(images, labels):
    images = tf.cast(images, tf.float32)
    labels = tf.cast(labels, tf.float32)
    images = images / 255.0
    images = tf.image.random_flip_left_right(images)
    images = tf.image.random_brightness(images, 0.1)
    images = tf.image.random_contrast(images, 0.9, 1.1)
    images = tf.clip_by_value(images, 0.0, 1.0)
    return images, labels

def preprocess_val_batch(images, labels):
    images = tf.cast(images, tf.float32) / 255.0
    labels = tf.cast(labels, tf.float32)
    return images, labels

train_ds = raw_train.map(augment_batch, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = raw_val.map(preprocess_val_batch, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)
test_ds = raw_test.map(preprocess_val_batch, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)

def apply_mixup(images, labels):
    batch_size = tf.shape(images)[0]
    alpha = MIXUP_ALPHA
    d1 = tf.random.gamma([batch_size], alpha, 1.0)
    d2 = tf.random.gamma([batch_size], alpha, 1.0)
    lam = tf.cast(d1 / (d1 + d2), tf.float32)
    lam_img = tf.reshape(lam, [batch_size, 1, 1, 1])
    lam_lbl = tf.reshape(lam, [batch_size, 1])
    idx = tf.random.shuffle(tf.range(batch_size))
    return lam_img * images + (1 - lam_img) * tf.gather(images, idx), \
           lam_lbl * labels + (1 - lam_lbl) * tf.gather(labels, idx)

if MIXUP_ALPHA > 0:
    train_ds = train_ds.map(apply_mixup, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ## Model Architecture

# %%
def build_model(input_shape=IMG_SIZE + (3,), num_classes=NUM_CLASSES):
    inputs = keras.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(DROPOUT * 0.3)(x)
    x = layers.Conv2D(128, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(128, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(DROPOUT * 0.5)(x)
    x = layers.Conv2D(256, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(256, 3, padding='same', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(DROPOUT)(x)
    x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(L2_WEIGHT))(x)
    x = layers.Dropout(DROPOUT * 0.5)(x)
    x = layers.Dense(num_classes)(x)
    outputs = layers.Activation('softmax', dtype='float32')(x)
    return keras.Model(inputs, outputs, name='quickdraw_cnn')

print("[INFO] Building model...")
model = build_model()
model.summary()
# Out:
# [INFO] Building model...
# Model: "quickdraw_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  batch_normalization_7 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  activation_8 (Activation)   (None, 128, 128, 32)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_8 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  activation_9 (Activation)   (None, 64, 64, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_9 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  activation_10 (Activation)  (None, 64, 64, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 128)       0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)       147584
#
#  batch_normalization_11 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_12 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 256)       0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)       590080
#
#  batch_normalization_13 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_14 (Activation)  (None, 16, 16, 256)       0
#
#  global_average_pooling2d_1   (None, 256)              0
#  (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 26)                13338
#
#  activation_15 (Activation)  (None, 26)                0
#
# =================================================================
# Total params: 1,311,642
# Trainable params: 1,309,786
# Non-trainable params: 1,856
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
optimizer = keras.optimizers.Adam(learning_rate=BASE_LR, clipnorm=1.0)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(
        label_smoothing=LABEL_SMOOTHING,
        from_logits=False
    ),
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc')]
)

try:
    counts_arr = np.array([class_counts.get(name, 1) for name in class_names])
    median = np.median(counts_arr)
    class_weights = {i: float(median / max(counts_arr[i], 1)) for i in range(NUM_CLASSES)}
    print(f"[INFO] Using class weights")
except:
    class_weights = None

# Force disable class weights for stability
class_weights = None
print(f"[INFO] Class weights disabled for stability")

callbacks = [
    keras.callbacks.ModelCheckpoint(
        BEST_CHECKPOINT,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    )
]

print(f"\n{'='*70}")
print(f"TRAINING START - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"{'='*70}\n")

start = time.time()

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)

elapsed = time.time() - start
print(f"\n[INFO] Training completed in {elapsed/60:.2f} minutes")

# Store baseline history for comparison
baseline_history = history.history
print(f"[INFO] Baseline history stored in 'baseline_history' variable")
# Out:
# [INFO] Using class weights
# [INFO] Class weights disabled for stability
#
# ======================================================================
# TRAINING START - 2025-12-14 05:42:48
# ======================================================================
#
# Epoch 1/30
# 244/244 [==============================] - ETA: 0s - loss: 2.7054 - accuracy: 0.2711 - top3_acc: 0.5203
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 91s 359ms/step - loss: 2.7054 - accuracy: 0.2711 - top3_acc: 0.5203 - val_loss: 7.9776 - val_accuracy: 0.0000e+00 - val_top3_acc: 0.1404 - lr: 1.0000e-04
# Epoch 2/30
# 244/244 [==============================] - ETA: 0s - loss: 1.9682 - accuracy: 0.5163 - top3_acc: 0.7796
# Epoch 2: val_accuracy improved from 0.00000 to 0.07630, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 89s 361ms/step - loss: 1.9682 - accuracy: 0.5163 - top3_acc: 0.7796 - val_loss: 3.4752 - val_accuracy: 0.0763 - val_top3_acc: 0.2427 - lr: 1.0000e-04
# Epoch 3/30
# 244/244 [==============================] - ETA: 0s - loss: 1.6686 - accuracy: 0.6206 - top3_acc: 0.8443
# Epoch 3: val_accuracy improved from 0.07630 to 0.53932, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 87s 354ms/step - loss: 1.6686 - accuracy: 0.6206 - top3_acc: 0.8443 - val_loss: 1.6969 - val_accuracy: 0.5393 - val_top3_acc: 0.8661 - lr: 1.0000e-04
# Epoch 4/30
# 244/244 [==============================] - ETA: 0s - loss: 1.5122 - accuracy: 0.6732 - top3_acc: 0.8738
# Epoch 4: val_accuracy did not improve from 0.53932
# 244/244 [==============================] - 80s 326ms/step - loss: 1.5122 - accuracy: 0.6732 - top3_acc: 0.8738 - val_loss: 1.9341 - val_accuracy: 0.4878 - val_top3_acc: 0.8138 - lr: 1.0000e-04
# Epoch 5/30
# 244/244 [==============================] - ETA: 0s - loss: 1.4216 - accuracy: 0.7060 - top3_acc: 0.8891
# Epoch 5: val_accuracy improved from 0.53932 to 0.58229, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 83s 339ms/step - loss: 1.4216 - accuracy: 0.7060 - top3_acc: 0.8891 - val_loss: 1.6552 - val_accuracy: 0.5823 - val_top3_acc: 0.8690 - lr: 1.0000e-04
# Epoch 6/30
# 244/244 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.7356 - top3_acc: 0.9016
# Epoch 6: val_accuracy improved from 0.58229 to 0.63984, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 92s 374ms/step - loss: 1.3422 - accuracy: 0.7356 - top3_acc: 0.9016 - val_loss: 1.4913 - val_accuracy: 0.6398 - val_top3_acc: 0.8958 - lr: 1.0000e-04
# Epoch 7/30
# 244/244 [==============================] - ETA: 0s - loss: 1.2904 - accuracy: 0.7513 - top3_acc: 0.9100
# Epoch 7: val_accuracy improved from 0.63984 to 0.67734, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 94s 380ms/step - loss: 1.2904 - accuracy: 0.7513 - top3_acc: 0.9100 - val_loss: 1.3823 - val_accuracy: 0.6773 - val_top3_acc: 0.9167 - lr: 1.0000e-04
# Epoch 8/30
# 244/244 [==============================] - ETA: 0s - loss: 1.2498 - accuracy: 0.7651 - top3_acc: 0.9182
# Epoch 8: val_accuracy improved from 0.67734 to 0.77135, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 108s 440ms/step - loss: 1.2498 - accuracy: 0.7651 - top3_acc: 0.9182 - val_loss: 1.1928 - val_accuracy: 0.7714 - val_top3_acc: 0.9378 - lr: 1.0000e-04
# Epoch 9/30
# 244/244 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.7816 - top3_acc: 0.9227
# Epoch 9: val_accuracy improved from 0.77135 to 0.82552, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 94s 384ms/step - loss: 1.2059 - accuracy: 0.7816 - top3_acc: 0.9227 - val_loss: 1.0888 - val_accuracy: 0.8255 - val_top3_acc: 0.9477 - lr: 1.0000e-04
# Epoch 10/30
# 244/244 [==============================] - ETA: 0s - loss: 1.1794 - accuracy: 0.7913 - top3_acc: 0.9267
# Epoch 10: val_accuracy did not improve from 0.82552
# 244/244 [==============================] - 84s 339ms/step - loss: 1.1794 - accuracy: 0.7913 - top3_acc: 0.9267 - val_loss: 1.1719 - val_accuracy: 0.7922 - val_top3_acc: 0.9344 - lr: 1.0000e-04
# Epoch 11/30
# 244/244 [==============================] - ETA: 0s - loss: 1.1492 - accuracy: 0.8004 - top3_acc: 0.9291
# Epoch 11: val_accuracy did not improve from 0.82552
# 244/244 [==============================] - 93s 377ms/step - loss: 1.1492 - accuracy: 0.8004 - top3_acc: 0.9291 - val_loss: 1.8894 - val_accuracy: 0.5448 - val_top3_acc: 0.7901 - lr: 1.0000e-04
# Epoch 12/30
# 244/244 [==============================] - ETA: 0s - loss: 1.1284 - accuracy: 0.8076 - top3_acc: 0.9329
# Epoch 12: val_accuracy improved from 0.82552 to 0.84453, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 80s 328ms/step - loss: 1.1284 - accuracy: 0.8076 - top3_acc: 0.9329 - val_loss: 1.0070 - val_accuracy: 0.8445 - val_top3_acc: 0.9591 - lr: 1.0000e-04
# Epoch 13/30
# 244/244 [==============================] - ETA: 0s - loss: 1.1059 - accuracy: 0.8146 - top3_acc: 0.9369
# Epoch 13: val_accuracy did not improve from 0.84453
# 244/244 [==============================] - 84s 342ms/step - loss: 1.1059 - accuracy: 0.8146 - top3_acc: 0.9369 - val_loss: 1.2395 - val_accuracy: 0.7576 - val_top3_acc: 0.9349 - lr: 1.0000e-04
# Epoch 14/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0866 - accuracy: 0.8207 - top3_acc: 0.9382
# Epoch 14: val_accuracy did not improve from 0.84453
# 244/244 [==============================] - 79s 320ms/step - loss: 1.0866 - accuracy: 0.8207 - top3_acc: 0.9382 - val_loss: 1.3212 - val_accuracy: 0.7466 - val_top3_acc: 0.8971 - lr: 1.0000e-04
# Epoch 15/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0651 - accuracy: 0.8271 - top3_acc: 0.9425
# Epoch 15: val_accuracy did not improve from 0.84453
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 244/244 [==============================] - 76s 310ms/step - loss: 1.0651 - accuracy: 0.8271 - top3_acc: 0.9425 - val_loss: 1.1075 - val_accuracy: 0.8206 - val_top3_acc: 0.9430 - lr: 1.0000e-04
# Epoch 16/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0423 - accuracy: 0.8364 - top3_acc: 0.9427
# Epoch 16: val_accuracy did not improve from 0.84453
# 244/244 [==============================] - 87s 353ms/step - loss: 1.0423 - accuracy: 0.8364 - top3_acc: 0.9427 - val_loss: 1.1277 - val_accuracy: 0.8115 - val_top3_acc: 0.9375 - lr: 5.0000e-05
# Epoch 17/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0233 - accuracy: 0.8424 - top3_acc: 0.9460
# Epoch 17: val_accuracy did not improve from 0.84453
# 244/244 [==============================] - 86s 348ms/step - loss: 1.0233 - accuracy: 0.8424 - top3_acc: 0.9460 - val_loss: 1.1071 - val_accuracy: 0.8122 - val_top3_acc: 0.9451 - lr: 5.0000e-05
# Epoch 18/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0198 - accuracy: 0.8437 - top3_acc: 0.9475
# Epoch 18: val_accuracy did not improve from 0.84453
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 244/244 [==============================] - 83s 339ms/step - loss: 1.0198 - accuracy: 0.8437 - top3_acc: 0.9475 - val_loss: 1.0836 - val_accuracy: 0.8294 - val_top3_acc: 0.9445 - lr: 5.0000e-05
# Epoch 19/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0010 - accuracy: 0.8492 - top3_acc: 0.9498
# Epoch 19: val_accuracy improved from 0.84453 to 0.87240, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 96s 391ms/step - loss: 1.0010 - accuracy: 0.8492 - top3_acc: 0.9498 - val_loss: 0.9252 - val_accuracy: 0.8724 - val_top3_acc: 0.9596 - lr: 2.5000e-05
# Epoch 20/30
# 244/244 [==============================] - ETA: 0s - loss: 1.0005 - accuracy: 0.8486 - top3_acc: 0.9485
# Epoch 20: val_accuracy did not improve from 0.87240
# 244/244 [==============================] - 72s 291ms/step - loss: 1.0005 - accuracy: 0.8486 - top3_acc: 0.9485 - val_loss: 0.9631 - val_accuracy: 0.8630 - val_top3_acc: 0.9557 - lr: 2.5000e-05
# Epoch 21/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9940 - accuracy: 0.8523 - top3_acc: 0.9497
# Epoch 21: val_accuracy improved from 0.87240 to 0.87500, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 73s 297ms/step - loss: 0.9940 - accuracy: 0.8523 - top3_acc: 0.9497 - val_loss: 0.9243 - val_accuracy: 0.8750 - val_top3_acc: 0.9599 - lr: 2.5000e-05
# Epoch 22/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9973 - accuracy: 0.8513 - top3_acc: 0.9489
# Epoch 22: val_accuracy improved from 0.87500 to 0.88620, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 76s 310ms/step - loss: 0.9973 - accuracy: 0.8513 - top3_acc: 0.9489 - val_loss: 0.8968 - val_accuracy: 0.8862 - val_top3_acc: 0.9628 - lr: 2.5000e-05
# Epoch 23/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9882 - accuracy: 0.8515 - top3_acc: 0.9506
# Epoch 23: val_accuracy did not improve from 0.88620
# 244/244 [==============================] - 75s 306ms/step - loss: 0.9882 - accuracy: 0.8515 - top3_acc: 0.9506 - val_loss: 0.9386 - val_accuracy: 0.8711 - val_top3_acc: 0.9581 - lr: 2.5000e-05
# Epoch 24/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9856 - accuracy: 0.8538 - top3_acc: 0.9519
# Epoch 24: val_accuracy did not improve from 0.88620
# 244/244 [==============================] - 83s 341ms/step - loss: 0.9856 - accuracy: 0.8538 - top3_acc: 0.9519 - val_loss: 0.9235 - val_accuracy: 0.8799 - val_top3_acc: 0.9599 - lr: 2.5000e-05
# Epoch 25/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9806 - accuracy: 0.8567 - top3_acc: 0.9528
# Epoch 25: val_accuracy did not improve from 0.88620
# 244/244 [==============================] - 73s 298ms/step - loss: 0.9806 - accuracy: 0.8567 - top3_acc: 0.9528 - val_loss: 0.8931 - val_accuracy: 0.8831 - val_top3_acc: 0.9620 - lr: 2.5000e-05
# Epoch 26/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9792 - accuracy: 0.8577 - top3_acc: 0.9521
# Epoch 26: val_accuracy did not improve from 0.88620
# 244/244 [==============================] - 73s 297ms/step - loss: 0.9792 - accuracy: 0.8577 - top3_acc: 0.9521 - val_loss: 0.8933 - val_accuracy: 0.8797 - val_top3_acc: 0.9635 - lr: 2.5000e-05
# Epoch 27/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9763 - accuracy: 0.8565 - top3_acc: 0.9530
# Epoch 27: val_accuracy improved from 0.88620 to 0.88880, saving model to best_scratch_ckpt.keras
# 244/244 [==============================] - 72s 295ms/step - loss: 0.9763 - accuracy: 0.8565 - top3_acc: 0.9530 - val_loss: 0.8772 - val_accuracy: 0.8888 - val_top3_acc: 0.9654 - lr: 2.5000e-05
# Epoch 28/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9704 - accuracy: 0.8586 - top3_acc: 0.9520
# Epoch 28: val_accuracy did not improve from 0.88880
# 244/244 [==============================] - 78s 319ms/step - loss: 0.9704 - accuracy: 0.8586 - top3_acc: 0.9520 - val_loss: 0.9150 - val_accuracy: 0.8786 - val_top3_acc: 0.9594 - lr: 2.5000e-05
# Epoch 29/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9661 - accuracy: 0.8587 - top3_acc: 0.9552
# Epoch 29: val_accuracy did not improve from 0.88880
# 244/244 [==============================] - 80s 322ms/step - loss: 0.9661 - accuracy: 0.8587 - top3_acc: 0.9552 - val_loss: 0.9406 - val_accuracy: 0.8656 - val_top3_acc: 0.9599 - lr: 2.5000e-05
# Epoch 30/30
# 244/244 [==============================] - ETA: 0s - loss: 0.9664 - accuracy: 0.8595 - top3_acc: 0.9541
# Epoch 30: val_accuracy did not improve from 0.88880
# 244/244 [==============================] - 93s 379ms/step - loss: 0.9664 - accuracy: 0.8595 - top3_acc: 0.9541 - val_loss: 0.8740 - val_accuracy: 0.8888 - val_top3_acc: 0.9651 - lr: 2.5000e-05
#
# [INFO] Training completed in 41.92 minutes
# [INFO] Baseline history stored in 'baseline_history' variable

# %%
import pickle

history_file = 'training_history.pkl'
with open(history_file, 'wb') as f:
    pickle.dump(history.history, f)
print(f"[INFO] Training history saved to {history_file}")
# Out:
# [INFO] Training history saved to training_history.pkl

# %% [markdown]
# ## Final Evaluation on Test Set

# %%
print("\n[INFO] Loading best model...")
if os.path.exists(BEST_CHECKPOINT):
    model = keras.models.load_model(BEST_CHECKPOINT)

print("[INFO] Final evaluation on test set...")
results = model.evaluate(test_ds, verbose=1, return_dict=True)

print(f"\n{'='*70}")
print("FINAL TEST RESULTS")
print(f"{'='*70}")
for name, value in results.items():
    print(f"  {name:20s}: {value:.4f}")
print(f"{'='*70}")

model.save(OUTPUT_MODEL)
print(f"\n[INFO] Saved: {OUTPUT_MODEL}")

best_val_acc = max(history.history['val_accuracy'])
print(f"\n[SUMMARY]")
print(f"  Classes: {NUM_CLASSES}")
print(f"  Images: {total_images:,}")
print(f"  Time: {elapsed/60:.2f} minutes")
print(f"  Best val accuracy: {best_val_acc:.4f}")
print(f"  Final test accuracy: {results['accuracy']:.4f}")
print(f"\nDONE! {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# [INFO] Loading best model...
# [INFO] Final evaluation on test set...
# 31/31 [==============================] - 5s 125ms/step - loss: 0.9073 - accuracy: 0.8836 - top3_acc: 0.9631
#
# ======================================================================
# FINAL TEST RESULTS
# ======================================================================
#   loss                : 0.9073
#   accuracy            : 0.8836
#   top3_acc            : 0.9631
# ======================================================================
#
# [INFO] Saved: quickdraw_scratch_final.keras
#
# [SUMMARY]
#   Classes: 26
#   Images: 39,000
#   Time: 41.92 minutes
#   Best val accuracy: 0.8888
#   Final test accuracy: 0.8836
#
# DONE! 2025-12-14 06:24:50

# %%
# Plot training history
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

# Plot loss
axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Load training history from saved file (if needed)
# Uncomment these lines if you need to reload history after closing VSCode

# import pickle
# with open('training_history.pkl', 'rb') as f:
#     history_dict = pickle.load(f)
# 
# # Then use history_dict instead of history.history in the plotting code below

# %% [markdown]
# ## Plot Training History (Alternative: Load from Saved File)

# %% [markdown]
# ## Visualization of Test Predictions

# %%
import matplotlib.pyplot as plt

samples_per_class = {cls: [] for cls in class_names}
max_per_class = 5

for images, labels in test_ds:
    preds = model.predict(images)
    pred_idx = np.argmax(preds, axis=1)
    true_idx = np.argmax(labels.numpy(), axis=1)

    for i in range(len(images)):
        cls = class_names[true_idx[i]]
        if len(samples_per_class[cls]) < max_per_class:
            samples_per_class[cls].append((
                images[i].numpy(),
                true_idx[i],
                pred_idx[i],
                preds[i][pred_idx[i]]
            ))

    if all(len(v) >= max_per_class for v in samples_per_class.values()):
        break

num_classes = len(class_names)
plt.figure(figsize=(15, 3 * num_classes))

for row, cls in enumerate(class_names):
    items = samples_per_class[cls]
    for col in range(len(items)):
        img, true_i, pred_i, conf = items[col]

        plt.subplot(num_classes, max_per_class, row * max_per_class + col + 1)
        plt.imshow(img)
        plt.axis("off")

        pred_label = class_names[pred_i]
        true_label = class_names[true_i]
        title = f"P:{pred_label}\nT:{true_label}\n({conf:.2f})"
        plt.title(title, fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 0s 15ms/step
# 4/4 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 36ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 31ms/step
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 1s 56ms/step
